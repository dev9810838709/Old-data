# %%
import pandas as pd

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePathOrBuffer', sep=<no_default>, delimiter=None, header='infer', names=<no_default>, index_col=None, usecols=None, squeeze=False, prefix=<no_default>, mangle_dupe_cols=True, dtype: 'DtypeArg | None' = None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: 'str' = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, encoding_errors: 'str | None' = 'strict', dialect=None, error_bad_lines=None, warn_bad_lines=None, on_bad_lines=None, delim_whitespace=False, low_memory=True, memory_map=Fals
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 4A61-45C6
#
#  Directory of C:\Users\Admin-ECS
#
# 14/03/2022  15:59    <DIR>          .
# 14/03/2022  15:59    <DIR>          ..
# 24/02/2022  12:08    <DIR>          .conda
# 11/03/2022  16:55    <DIR>          .ipynb_checkpoints
# 16/12/2021  13:11    <DIR>          .ipython
# 16/12/2021  15:16    <DIR>          .jupyter
# 19/09/2021  16:30    <DIR>          .vscode
# 07/02/2022  15:39    <DIR>          __pycache__
# 17/10/2020  22:25    <DIR>          3D Objects
# 16/12/2021  11:59    <DIR>          anaconda3
# 13/03/2022  10:19         5,881,081 Annual.csv
# 12/08/2021  00:13               151 BullseyeCoverageError.txt
# 11/03/2022  16:49             3,477 Cassandra.ipynb
# 26/02/2022  18:21            10,988 Class  Oops inheritence.ipynb
# 17/10/2020  22:25    <DIR>          Contacts
# 19/12/2021  10:13    <DIR>          Desktop
# 24/02/2022  01:31    <DIR>          Documents
# ...

# %%
pd.read_csv('Sudhir.csv')
# Out:
#     name            emailid    address  pincode sirname
# 0    Sudh     dev@gmail.com      delhi   110061   kumar
# 1     dev   kumar@gmail.com   bijwasan   110092  parsad
# 2    raja     raj@gmail.com    salapur   110063   singh
# 3  rajesh  rajesh@gmail.com  kapashera   110045    puri

# %%
pd.read_csv('Annual.csv')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df = pd.read_csv('Annual.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('Sudhir.csv',header=None)
# Out:
#         0                 1          2        3        4
# 0   name            emailid    address  pincode  sirname
# 1    Sudh     dev@gmail.com      delhi   110061    kumar
# 2     dev   kumar@gmail.com   bijwasan   110092   parsad
# 3    raja     raj@gmail.com    salapur   110063    singh
# 4  rajesh  rajesh@gmail.com  kapashera   110045     puri

# %%
pd.read_csv('Sudhir.csv',names=["a","b","c","d","e"])
# Out:
#         a                 b          c        d        e
# 0   name            emailid    address  pincode  sirname
# 1    Sudh     dev@gmail.com      delhi   110061    kumar
# 2     dev   kumar@gmail.com   bijwasan   110092   parsad
# 3    raja     raj@gmail.com    salapur   110063    singh
# 4  rajesh  rajesh@gmail.com  kapashera   110045     puri

# %%
pd.read_csv('Sudhir.csv',names=["a","b","c","d","e","f"])
# Out:
#         a                 b          c        d        e   f
# 0   name            emailid    address  pincode  sirname NaN
# 1    Sudh     dev@gmail.com      delhi   110061    kumar NaN
# 2     dev   kumar@gmail.com   bijwasan   110092   parsad NaN
# 3    raja     raj@gmail.com    salapur   110063    singh NaN
# 4  rajesh  rajesh@gmail.com  kapashera   110045     puri NaN

# %%
pd.read_csv('Sudhir.csv',names=["a","b","c"])
# Out:
#                                  a        b        c
# name   emailid             address  pincode  sirname
# Sudh   dev@gmail.com         delhi   110061    kumar
# dev    kumar@gmail.com    bijwasan   110092   parsad
# raja   raj@gmail.com       salapur   110063    singh
# rajesh rajesh@gmail.com  kapashera   110045     puri

# %%
pd.read_csv('Sudhir.csv',sep='@')
# Out:
#               name ,emailid,address,pincode,sirname
# Sudh,dev               gmail.com,delhi,110061,kumar
# dev,kumar          gmail.com,bijwasan,110092,parsad
# raja,raj             gmail.com,salapur,110063,singh
# rajesh,rajesh       gmail.com,kapashera,110045,puri

# %%
pd.read_csv('Sudhir.csv',sep=',')
# Out:
#     name            emailid    address  pincode sirname
# 0    Sudh     dev@gmail.com      delhi   110061   kumar
# 1     dev   kumar@gmail.com   bijwasan   110092  parsad
# 2    raja     raj@gmail.com    salapur   110063   singh
# 3  rajesh  rajesh@gmail.com  kapashera   110045    puri

# %%
pd.read_csv('Sudhir.csv',skiprows=[1,3])
# Out:
#     name            emailid    address  pincode sirname
# 0     dev   kumar@gmail.com   bijwasan   110092  parsad
# 1  rajesh  rajesh@gmail.com  kapashera   110045    puri

# %%
pd.read_csv('Annual.csv')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df1=pd.read_csv('Annual.csv')

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
df1.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2020                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
# 2  2020                     Level 1                99999       All industries
# 3  2020                     Level 1                99999       All industries
# 4  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df1.head(2)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2020                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
#
#      Value                             Industry_code_ANZSIC06
# 0  733,258  ANZSIC06 divisions A-S (excluding classes K633...
# 1  660,630  ANZSIC06 divisions A-S (excluding classes K633...

# %%
df1.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 37075  Food product manufacturing  Percentage           H37
# 37076  Food product manufacturing  Percentage           H38
# 37077  Food product manufacturing  Percentage           H39
# 37078  Food product manufacturing  Percentage           H40
# 37079  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 37075                          Quick ratio  Financial ratios    52
# 37076  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
df1.tail(3)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 37077  Food product manufacturing  Percentage           H39
# 37078  Food product manufacturing  Percentage           H40
# 37079  Food product manufacturing  Percentage           H41
#
#                 Variable_name Variable_category Value  \
# 37077        Return on equity  Financial ratios    12
# 37078  Return on total assets  Financial ratios     5
# 37079   Liabilities structure  Financial ratios    46
#
#                                   Industry_code_ANZSIC06
# 37077  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37078  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37079  ANZSIC06 groups C111, C112, C113, C114, C115, ...

# %%
pd.read_csv('Annual.csv').columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
df1['Variable_name']
# Out:
# 0                                           Total income
# 1        Sales, government funding, grants and subsidies
# 2                      Interest, dividends and donations
# 3                                   Non-operating income
# 4                                      Total expenditure
#                               ...
# 37075                                        Quick ratio
# 37076                Margin on sales of goods for resale
# 37077                                   Return on equity
# 37078                             Return on total assets
# 37079                              Liabilities structure
# Name: Variable_name, Length: 37080, dtype: object

# %%
a = df1['Variable_name']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df1[['Variable_name','Value']]
# Out:
#                                          Variable_name    Value
# 0                                         Total income  733,258
# 1      Sales, government funding, grants and subsidies  660,630
# 2                    Interest, dividends and donations   54,342
# 3                                 Non-operating income   18,285
# 4                                    Total expenditure  654,872
# ...                                                ...      ...
# 37075                                      Quick ratio       52
# 37076              Margin on sales of goods for resale       40
# 37077                                 Return on equity       12
# 37078                           Return on total assets        5
# 37079                            Liabilities structure       46
#
# [37080 rows x 2 columns]

# %%
df1[['Variable_name','Value','Units']]
# Out:
#                                          Variable_name    Value  \
# 0                                         Total income  733,258
# 1      Sales, government funding, grants and subsidies  660,630
# 2                    Interest, dividends and donations   54,342
# 3                                 Non-operating income   18,285
# 4                                    Total expenditure  654,872
# ...                                                ...      ...
# 37075                                      Quick ratio       52
# 37076              Margin on sales of goods for resale       40
# 37077                                 Return on equity       12
# 37078                           Return on total assets        5
# 37079                            Liabilities structure       46
#
#                     Units
# 0      Dollars (millions)
# 1      Dollars (millions)
# 2      Dollars (millions)
# 3      Dollars (millions)
# 4      Dollars (millions)
# ...                   ...
# ...

# %%
df2 = df1[['Variable_name','Value','Units']]

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = df1[['Variable_name']]

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 4A61-45C6
#
#  Directory of C:\Users\Admin-ECS
#
# 14/03/2022  17:38    <DIR>          .
# 14/03/2022  17:38    <DIR>          ..
# 24/02/2022  12:08    <DIR>          .conda
# 11/03/2022  16:55    <DIR>          .ipynb_checkpoints
# 16/12/2021  13:11    <DIR>          .ipython
# 16/12/2021  15:16    <DIR>          .jupyter
# 19/09/2021  16:30    <DIR>          .vscode
# 07/02/2022  15:39    <DIR>          __pycache__
# 17/10/2020  22:25    <DIR>          3D Objects
# 16/12/2021  11:59    <DIR>          anaconda3
# 13/03/2022  10:19         5,881,081 Annual.csv
# 12/08/2021  00:13               151 BullseyeCoverageError.txt
# 11/03/2022  16:49             3,477 Cassandra.ipynb
# 26/02/2022  18:21            10,988 Class  Oops inheritence.ipynb
# 17/10/2020  22:25    <DIR>          Contacts
# 19/12/2021  10:13    <DIR>          Desktop
# 24/02/2022  01:31    <DIR>          Documents
# ...

# %%
df2 = df1[['Variable_name']]

# %%
pd.read_csv('Sudhir.csv')
# Out:
#     name            emailid    address  pincode sirname
# 0    Sudh     dev@gmail.com      delhi   110061   kumar
# 1     dev   kumar@gmail.com   bijwasan   110092  parsad
# 2    raja     raj@gmail.com    salapur   110063   singh
# 3  rajesh  rajesh@gmail.com  kapashera   110045    puri

# %%
pd.read_excel('Test file.xlsx')
# Out:
#      name            email id   address         mob
# 0   Sudhir   Sudhir@gmail.com   Salapur   9856626.0
# 1     RaHA     RaHA@gmail.com       GGN     95582.0
# 2  mandeep  mandeep@gmail.com     Delhi   9823655.0
# 3     monu     monu@gmail.com  bijwasan  78266663.0

# %%
pd.read_excel('Test file.xlsx')
# Out:
#      name            email id   address         mob
# 0   Sudhir   Sudhir@gmail.com   Salapur   9856626.0
# 1     RaHA     RaHA@gmail.com       GGN     95582.0
# 2  mandeep  mandeep@gmail.com     Delhi   9823655.0
# 3     monu     monu@gmail.com  bijwasan  78266663.0

# %%
pd.ExcelFile('Test file.xlsx')

# %%
df3 = pd.ExcelFile('Test file.xlsx')

# %%
df3.sheet_names
# Out:
# ['Student', 'teacher', 'Records']

# %%
pd.read_excel('Test file.xlsx', sheet_name = "teacher")
# Out:
#    name 12          email ids        address  mob number
# 0  Sudhir1   Sudhir@gmail.com  Salapur khera  96356332.0
# 1    kumar     RaHA@gmail.com        Gurgaon   2556322.0
# 2  rakaesj  mandeep@gmail.com          Delhi   3236923.0
# 3  manohar     monu@gmail.com       sector21    533215.0

# %%
pd.read_excel('Test file.xlsx', sheet_name = "Records")
# Out:
#      names          email ids   address real     mob no.
# 0  Sudhir1   Sudhir@gmail.com  Salapur khera  96356332.0
# 1    kumar     RaHA@gmail.com        Gurgaon   2556322.0
# 2  rakaesj  mandeep@gmail.com          Delhi   3236923.0
# 3  manohar     monu@gmail.com       sector21    533215.0

# %%
pd.ExcelFile('Test file.xlsx')

# %%
df3 = pd.ExcelFile('Test file.xlsx')

# %%
df3.sheet_names
# Out:
# ['Student', 'teacher', 'Records']

# %%
for i in df3.sheet_names:
    pd.read_excel('Test file.xlsx', sheet_name = i)

# %%
print(i)
# Out:
# Records

# %%
pd.read_csv('https://Raw.gist.github.com/suellenstringer-hye/f2231b3383538bcb1a5b051c7908f5b7')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# ...
